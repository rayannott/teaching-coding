# %% [markdown]
# This notebook continues with the comprehension syntax for dictionaries, sets and generators.

# %% [markdown]
# ## `dict` comprehension

# %% [markdown]
# ## `set` comprehension

# %% [markdown]
# ## Generator comprehension
