# %% [markdown]
# # Mathematical Programming
#
# Please take a look at the following problems and do not try to solve them via brute force.

# %% [markdown]
# ## Problem 1. Polynomial Roots
#
# Find the smallest natural number $n$ such that $b-1$ does not divide into $b^n - 1$ or prove that such number does not exist.

# %%
def problem1() -> int:
    ...

# %% [markdown]
# ## Problem 2. Big Fibonacci Number
#
# Find the index of the first fibonacci number to have more than 100 digits.
# Consider that
# $$
# F_0 = 0,\;\;F_1 = 1; \;\;\; F_n = F_{n-1} + F_{n-2} \;\;\; \forall n \geq 2.
# $$

# %%
def problem2() -> int:
    ...

# %% [markdown]
# ## Problem 3. Integer Triangles with Perimeter L
#
# You are given an integer L, representing the perimeter of a triangle.
# Find the number of unique triangles that can be formed with positive integer side lengths,
# where the sum of the lengths equals the given perimeter L.
#
# Note: "unique" means that the triangles (2, 2, 3), (2, 3, 2) and (3, 2, 2)
# are considered the same since they have
# the same side lengths.
#
# For example, there are 5 unique triangles that can be formed with L = 13:\
# `(1, 6, 6), (2, 5, 6), (3, 4, 6), (3, 5, 5), (4, 4, 5)`

# %%
def problem3(perimeter: float) -> int:
    ...

# %% [markdown]
# ## Problem 4. Egyptian Fractions
#
# Egyptian fraction is a finite sum of distinct unit fractions, i.e. fractions of the form $\frac{1}{n}$. For example, $\frac{3}{7} = \frac{1}{3} + \frac{1}{11} + \frac{1}{231}$.
#
# Given a numerator $p$ and a denominator $q$ such that `gcd(p, q) == 1` and $p < q$ find the Egyptian fraction representation of $\frac{p}{q}$:
# ```python
# >>> egyptian_fraction(3, 7)
# [3, 11, 231]
# ```

# %%
import math


def problem4(p: int, q: int) -> list[int]:
    # assert math.gcd(p, q) == 1 and p < q
    ...

# %% [markdown]
# ## Problem 6. Simple Linear Regression
#
# Given a set of points $(x_1, y_1), (x_2, y_2), \ldots, (x_n, y_n)$, $n>1$, with distinct values for $x$ find the _best fit line*_ that minimizes the mean squared error:
# $$
# \text{MSE}(k, b) = \frac{1}{n}\sum_{i=1}^{n} (kx_i + b - y_i)^2.
# $$
# In other words, find
# $$
# k, b = \argmin_{k, b} \text{MSE}(k, b).
# $$
# *the _best fit line_ is given by the equation $y = kx + b$ where $k$ is the slope and $b$ is the y-intercept.

# %%
import numpy as np


def best_line_np(points: list[tuple[float, float]]) -> tuple[float, float]:
    """The best line using numpy.polyfit.
    Use this function to test your implementation."""
    xs, ys = zip(*points)
    coefs = np.polyfit(xs, ys, 1)
    return coefs[0], coefs[1]


def generate_points(k: float, b: float, n: int) -> list[tuple[float, float]]:
    """Generate n points close to the line y = kx + b."""
    xs = np.random.random(n) * 10 - 5
    xs.sort()
    ys = k * xs + b + np.random.randn(n)
    return list(zip(xs, ys))


def best_line(points: list[tuple[float, float]]) -> tuple[float, float]:
    ...

# %% [markdown]
# Run the next cell to visualize the points forming a line.

# %%
from matplotlib import pyplot as plt

points = generate_points(3, 5, 100)
xs, ys = zip(*points)
plt.scatter(xs, ys, color="r", s=10)

# the following adds a line to the plot
k, b = best_line_np(points)  # change to best_line to test your implementation
plt.plot(xs, [k * x + b for x in xs], color="b")

plt.grid()
plt.show()

# %% [markdown]
# ## Problem 7. Perfect Squares
#
# Given a number $a$, find a number of positive perfect squares smaller than $a$.
#
# A perfect square is a number $n$ such that there exists an integer $m$ s.t. $n = m^2$.

# %%
def is_perfect_square(n: int) -> bool:
    """
    Check if n is a perfect square number.

    >>> is_perfect_square(16)
    True
    >>> is_perfect_square(15)
    False
    """
    ...


def number_of_squares(a: float) -> int:
    """
    Count the number of perfect square numbers less than a.
    Possibly, you can use is_perfect_square.

    >>> number_of_squares(2)
    1
    >>> number_of_squares(10) # 1, 4, 9 -> 3
    3
    >>> number_of_squares(100)
    9
    """
    ...

# %% [markdown]
# ## Problem 8.
