# %% [markdown]
# # The Beginnings of Calculus

# %% [markdown]
# ## Sequences and limits

# %% [markdown]
# ## Derivatives

# %%
from typing import Callable

_dx = 1e-12


def derivative(f: Callable[[float], float]) -> Callable[[float], float]: ...

# %% [markdown]
# ## Series

# %% [markdown]
# ## Integrals

# %% [markdown]
# # Fundamental functions and constants
#
# Use the definitions of the following mathematical functions and constants (or other statements featuring them) to compute their approximate values. Make sure the main statements hold for any reasonable inputs.

# %% [markdown]
# ## The number $e$
# [Series and limit definitions](https://en.wikipedia.org/wiki/E_(mathematical_constant)#Definitions)
#
# Check the derivative of $e^x$.

# %%
def number_e_series() -> float: ...


def number_e_limit() -> float: ...


_E = number_e_series()


def e(x: float) -> float:
    return _E**x

# %% [markdown]
# ## The `sin` function
# [Series definition](https://en.wikipedia.org/wiki/Sine_and_cosine#Series_definitions)

# %%
def sine_function(x: float) -> float: ...

# %% [markdown]
# ## The number $\pi$
# [Series definitions](https://en.wikipedia.org/wiki/Pi#Infinite_series)
#
# [Integral definition](https://en.wikipedia.org/wiki/Pi#Definition)

# %%
def pi_series() -> float: ...


def pi_integral() -> float: ...

# %% [markdown]
# ## The `log` function
#
# [Limit definition](https://en.wikipedia.org/wiki/Natural_logarithm#Inverse_of_exponential)
#
# [Integral definition](https://en.wikipedia.org/wiki/Logarithm#Integral_representation_of_the_natural_logarithm)
#
# [Series definition](https://en.wikipedia.org/wiki/Natural_logarithm#Series)
#
# Check the rules $\log(a \cdot b) = \log(a) + \log(b)$ and $\log(a^b) = b \cdot \log(a)$.

# %%
def log_limit(x: float) -> float: ...


def log_integral(x: float) -> float: ...


def log_series(x: float) -> float: ...
